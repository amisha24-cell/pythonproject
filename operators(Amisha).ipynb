# %% [markdown]
# ### Operators

# %%
a = 10

# %%
b = 10

# %%
a + b
# Out:
# 20

# %%
a - b
# Out:
# 0

# %%
a * b
# Out:
# 100

# %%
a / b
# Out:
# 1.0

# %%
a // b
# Out:
# 1

# %%
a % b
# Out:
# 0

# %% [markdown]
# ### Logical operators

# %%
# and,or 
#And : if two condition are true then result will be true, if the one condition will false then the result will false
#or : if one condition is true from both condition then the result will be true
a = 20

# %%
b = 20

# %%
a > 20 & b > 20
# Out:
# False

# %%
a >= 20 | b >= 20
# Out:
# True

# %% [markdown]
# ### Comparative operator

# %%
a = 20

# %%
b = 15

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a == b
# Out:
# False

# %% [markdown]
# ### Assignement operator

# %%
a = 40

# %%
b = a+10

# %%
b
# Out:
# 50

# %%
a+10
# Out:
# 50

# %%
b+20
# Out:
# 70

# %%
a+=10 # it not returns the value it add only into assignment

# %%
b = a-10

# %%
b
# Out:
# 40

# %%
b = a*10

# %%
b
# Out:
# 500

# %%
b = a/10

# %%
b
# Out:
# 5.0

# %%
del str

# %%
name1 = "Roohi"

# %%
print(isinstance(name1, str))
# Out:
# True
